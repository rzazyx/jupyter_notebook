# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv', encoding='latin1', header=None, low_memory=False)

# %%
df.columns = ['province_id', 'province_name', 'city_id', 'city_name', 'district_id', 'district', 
              'npsn', 'school_name', 'stage', 'status', 'street_name', 'lat', 'long']

# %%
df.head()
# Out:
#    province_id  province_name  city_id      city_name  district_id  \
# 0  province_id  province_name  city_id      city_name  district_id
# 1       250000          Papua   251800  Kab. Tolikara       251831
# 2       250000          Papua   251800  Kab. Tolikara       251822
# 3       250000          Papua   251800  Kab. Tolikara       251803
# 4       250000          Papua   251800  Kab. Tolikara       251814
#
#            district      npsn        school_name  stage  status  street_name  \
# 0          district      npsn        school_name  stage  status  street_name
# 1  Kec. Gilungbandu  60303704     SMP SATAP KAGI    SMP       N    Gilubandu
# 2        Kec. Wunin  60302267  SD YPPGI WURINERI     SD       S        Wunin
# 3    Kec. Bokondini  60302279     SMAN BOKONDINI    SMA       N      MAIRINI
# 4        Kec. Kuari  60302215    SD INPRES KUARI     SD       N        Kuari
#
#           lat         long
# 0         lat         long
# 1  -3.4159950  138.3397040
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215373 entries, 0 to 215372
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   province_id    215373 non-null  object
#  1   province_name  215373 non-null  object
#  2   city_id        215373 non-null  object
#  3   city_name      215373 non-null  object
#  4   district_id    215373 non-null  object
#  5   district       215373 non-null  object
#  6   npsn           215373 non-null  object
#  7   school_name    215373 non-null  object
#  8   stage          215373 non-null  object
#  9   status         215373 non-null  object
#  10  street_name    215371 non-null  object
#  11  lat            214223 non-null  object
#  12  long           214223 non-null  object
# dtypes: object(13)
# memory usage: 21.4+ MB

# %%
df.describe()
# Out:
#        province_id province_name city_id   city_name district_id  \
# count       215373        215373  215373      215373      215373
# unique          35            35     515         521        6920
# top          20000    Jawa Barat   20500  Kab. Bogor       16207
# freq         29532         29532    2955        2955         231
#
#                district      npsn      school_name   stage  status  \
# count            215373    215373           215373  215373  215373
# unique             6573    215372           203109       9       3
# top     Kec. Banjarsari  10263519  SD MUHAMMADIYAH      SD       N
# freq                284         2               47  148479  166417
#
#                street_name       lat      long
# count               215371    214223    214223
# unique              183814    112489    148494
# top     Jl. Trans Sulawesi  .0000000  .0000000
# freq                   247       184       656

# %%
df.isnull().sum()
# Out:
# province_id         0
# province_name       0
# city_id             0
# city_name           0
# district_id         0
# district            0
# npsn                0
# school_name         0
# stage               0
# status              0
# street_name         2
# lat              1150
# long             1150
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.isnull().any(axis=1)]
# Out:
#        province_id province_name city_id           city_name district_id  \
# 50          250000         Papua  253000     Kab. Lanny Jaya      253003
# 214         250000         Papua  253200         Kab. Yalimo      253204
# 248         250000         Papua  253300         kab. Puncak      253302
# 267         250000         Papua  253300         kab. Puncak      253301
# 440         260000      Bengkulu  260200  Kab. Rejang Lebong      260222
# ...            ...           ...     ...                 ...         ...
# 215130      250000         Papua  251600       Kab. Yahukimo      251627
# 215153      250000         Papua  251600       Kab. Yahukimo      251637
# 215170      250000         Papua  251600       Kab. Yahukimo      251632
# 215232      250000         Papua  251600       Kab. Yahukimo      251630
# 215250      250000         Papua  251600       Kab. Yahukimo      251610
#
#                  district      npsn                  school_name stage status  \
# ...
